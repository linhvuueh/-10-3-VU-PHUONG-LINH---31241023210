# %% [markdown]
# <a href="https://colab.research.google.com/github/linhvuueh/-10-3-VU-PHUONG-LINH---31241023210/blob/main/%5BCIFAR_100%5D_VU_PHUONG_LINH_31241023210.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from re import X
from keras.datasets import cifar100
(X_train,y_train),(X_test,y_test)=cifar100.load_data()
X_train=X_train.reshape(50000,32*32*3)
X_train=X_train.astype('float32')/255
X_test=X_test.reshape(10000,32*32*3)
X_test=X_test.astype('float32')/255
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout # Import Dropout here
y_train=to_categorical(y_train)
y_test=to_categorical(y_test)
model = Sequential()
model.add(Dense(512, input_shape=(3072,), activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(112, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(100, activation='softmax'))
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
history = model.fit(X_train, y_train, epochs=70, batch_size=64, validation_data=(X_test, y_test))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 512)                 │       1,573,376 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 112)                 │          28,784 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 112)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 100)                 │          11,300 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,744,788 (6.66 MB)
#  Trainable params: 1,744,788 (6.66 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 31ms/step - accuracy: 0.0232 - loss: 4.5202 - val_accuracy: 0.0691 - val_loss: 4.0814
# Epoch 2/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.0614 - loss: 4.1177 - val_accuracy: 0.1000 - val_loss: 3.9437
# Epoch 3/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.0795 - loss: 3.9906 - val_accuracy: 0.1175 - val_loss: 3.8310
# Epoch 4/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.0964 - loss: 3.8894 - val_accuracy: 0.1238 - val_loss: 3.7943
# Epoch 5/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.1027 - loss: 3.8419 - val_accuracy: 0.1423 - val_loss: 3.6735
# Epoch 6/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.1129 - loss: 3.7939 - val_accuracy: 0.1440 - val_loss: 3.6683
# Epoch 7/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - accuracy: 0.1207 - loss: 3.7534 - val_accuracy: 0.1479 - val_loss: 3.6438
# Epoch 8/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.1224 - loss: 3.7248 - val_accuracy: 0.1607 - val_loss: 3.6141
# Epoch 9/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 31ms/step - accuracy: 0.1271 - loss: 3.7050 - val_accuracy: 0.1403 - val_loss: 3.6653
# Epoch 10/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - accuracy: 0.1262 - loss: 3.6976 - val_accuracy: 0.1572 - val_loss: 3.5803
# Epoch 11/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.1305 - loss: 3.6759 - val_accuracy: 0.1635 - val_loss: 3.5570
# Epoch 12/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.1350 - loss: 3.6598 - val_accuracy: 0.1653 - val_loss: 3.5518
# Epoch 13/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.1380 - loss: 3.6400 - val_accuracy: 0.1678 - val_loss: 3.5380
# Epoch 14/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.1401 - loss: 3.6191 - val_accuracy: 0.1640 - val_loss: 3.5363
# Epoch 15/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.1427 - loss: 3.6116 - val_accuracy: 0.1740 - val_loss: 3.5077
# Epoch 16/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 35ms/step - accuracy: 0.1432 - loss: 3.6046 - val_accuracy: 0.1750 - val_loss: 3.4945
# Epoch 17/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 38ms/step - accuracy: 0.1421 - loss: 3.5923 - val_accuracy: 0.1618 - val_loss: 3.5299
# Epoch 18/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 36ms/step - accuracy: 0.1449 - loss: 3.5840 - val_accuracy: 0.1718 - val_loss: 3.5135
# Epoch 19/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.1477 - loss: 3.5761 - val_accuracy: 0.1652 - val_loss: 3.5542
# Epoch 20/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.1454 - loss: 3.5782 - val_accuracy: 0.1697 - val_loss: 3.5150
# Epoch 21/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.1489 - loss: 3.5701 - val_accuracy: 0.1668 - val_loss: 3.5343
# Epoch 22/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 32ms/step - accuracy: 0.1495 - loss: 3.5566 - val_accuracy: 0.1784 - val_loss: 3.4776
# Epoch 23/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.1541 - loss: 3.5433 - val_accuracy: 0.1730 - val_loss: 3.5008
# Epoch 24/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 33ms/step - accuracy: 0.1558 - loss: 3.5438 - val_accuracy: 0.1816 - val_loss: 3.4742
# Epoch 25/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.1564 - loss: 3.5274 - val_accuracy: 0.1715 - val_loss: 3.5024
# Epoch 26/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.1507 - loss: 3.5427 - val_accuracy: 0.1792 - val_loss: 3.4615
# Epoch 27/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.1585 - loss: 3.5080 - val_accuracy: 0.1852 - val_loss: 3.4531
# Epoch 28/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 29s 37ms/step - accuracy: 0.1568 - loss: 3.5371 - val_accuracy: 0.1824 - val_loss: 3.4318
# Epoch 29/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 31s 40ms/step - accuracy: 0.1628 - loss: 3.5065 - val_accuracy: 0.1788 - val_loss: 3.4712
# Epoch 30/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 37ms/step - accuracy: 0.1565 - loss: 3.5146 - val_accuracy: 0.1851 - val_loss: 3.4256
# Epoch 31/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.1618 - loss: 3.4976 - val_accuracy: 0.1834 - val_loss: 3.4498
# Epoch 32/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.1576 - loss: 3.5028 - val_accuracy: 0.1831 - val_loss: 3.4469
# Epoch 33/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 36ms/step - accuracy: 0.1648 - loss: 3.4788 - val_accuracy: 0.1791 - val_loss: 3.4562
# Epoch 34/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.1638 - loss: 3.4885 - val_accuracy: 0.1896 - val_loss: 3.4340
# Epoch 35/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.1587 - loss: 3.4864 - val_accuracy: 0.1791 - val_loss: 3.4581
# Epoch 36/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.1596 - loss: 3.5016 - val_accuracy: 0.1902 - val_loss: 3.4264
# Epoch 37/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 34ms/step - accuracy: 0.1629 - loss: 3.4766 - val_accuracy: 0.1892 - val_loss: 3.4129
# Epoch 38/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.1632 - loss: 3.4675 - val_accuracy: 0.1843 - val_loss: 3.4407
# Epoch 39/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 27s 35ms/step - accuracy: 0.1633 - loss: 3.4825 - val_accuracy: 0.1731 - val_loss: 3.5189
# Epoch 40/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - accuracy: 0.1666 - loss: 3.4816 - val_accuracy: 0.1830 - val_loss: 3.4548
# Epoch 41/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.1659 - loss: 3.4711 - val_accuracy: 0.1843 - val_loss: 3.4344
# Epoch 42/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 35ms/step - accuracy: 0.1646 - loss: 3.4953 - val_accuracy: 0.1775 - val_loss: 3.4610
# Epoch 43/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 32ms/step - accuracy: 0.1671 - loss: 3.4705 - val_accuracy: 0.1852 - val_loss: 3.4475
# Epoch 44/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.1687 - loss: 3.4536 - val_accuracy: 0.1855 - val_loss: 3.4304
# Epoch 45/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.1679 - loss: 3.4747 - val_accuracy: 0.1867 - val_loss: 3.4249
# Epoch 46/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 32ms/step - accuracy: 0.1643 - loss: 3.4679 - val_accuracy: 0.1817 - val_loss: 3.4410
# Epoch 47/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.1646 - loss: 3.4635 - val_accuracy: 0.1741 - val_loss: 3.5034
# Epoch 48/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 36ms/step - accuracy: 0.1710 - loss: 3.4487 - val_accuracy: 0.1915 - val_loss: 3.4015
# Epoch 49/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 35ms/step - accuracy: 0.1698 - loss: 3.4471 - val_accuracy: 0.1862 - val_loss: 3.4373
# Epoch 50/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.1660 - loss: 3.4569 - val_accuracy: 0.1893 - val_loss: 3.4223
# Epoch 51/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.1717 - loss: 3.4441 - val_accuracy: 0.1869 - val_loss: 3.4322
# Epoch 52/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 25s 32ms/step - accuracy: 0.1697 - loss: 3.4460 - val_accuracy: 0.1845 - val_loss: 3.4605
# Epoch 53/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 32ms/step - accuracy: 0.1676 - loss: 3.4515 - val_accuracy: 0.1941 - val_loss: 3.3932
# Epoch 54/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.1714 - loss: 3.4342 - val_accuracy: 0.1887 - val_loss: 3.4100
# Epoch 55/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 31ms/step - accuracy: 0.1697 - loss: 3.4428 - val_accuracy: 0.1959 - val_loss: 3.3864
# Epoch 56/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.1697 - loss: 3.4372 - val_accuracy: 0.1922 - val_loss: 3.4034
# Epoch 57/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 34ms/step - accuracy: 0.1699 - loss: 3.4397 - val_accuracy: 0.1902 - val_loss: 3.4089
# Epoch 58/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.1716 - loss: 3.4382 - val_accuracy: 0.1847 - val_loss: 3.4233
# Epoch 59/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 26s 33ms/step - accuracy: 0.1722 - loss: 3.4276 - val_accuracy: 0.1915 - val_loss: 3.3884
# Epoch 60/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 33ms/step - accuracy: 0.1689 - loss: 3.4356 - val_accuracy: 0.1943 - val_loss: 3.4228
# Epoch 61/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 41ms/step - accuracy: 0.1703 - loss: 3.4311 - val_accuracy: 0.1985 - val_loss: 3.3814
# Epoch 62/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 33ms/step - accuracy: 0.1735 - loss: 3.4314 - val_accuracy: 0.1885 - val_loss: 3.4084
# Epoch 63/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 32ms/step - accuracy: 0.1718 - loss: 3.4267 - val_accuracy: 0.1926 - val_loss: 3.4228
# Epoch 64/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 33ms/step - accuracy: 0.1680 - loss: 3.4355 - val_accuracy: 0.2004 - val_loss: 3.3961
# Epoch 65/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 36ms/step - accuracy: 0.1708 - loss: 3.4291 - val_accuracy: 0.1889 - val_loss: 3.4040
# Epoch 66/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 28s 35ms/step - accuracy: 0.1722 - loss: 3.4259 - val_accuracy: 0.1922 - val_loss: 3.4112
# Epoch 67/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 32s 41ms/step - accuracy: 0.1726 - loss: 3.4165 - val_accuracy: 0.1946 - val_loss: 3.3878
# Epoch 68/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 39ms/step - accuracy: 0.1771 - loss: 3.4038 - val_accuracy: 0.1926 - val_loss: 3.4057
# Epoch 69/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 37ms/step - accuracy: 0.1741 - loss: 3.4137 - val_accuracy: 0.1859 - val_loss: 3.4366
# Epoch 70/70
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 35ms/step - accuracy: 0.1771 - loss: 3.4111 - val_accuracy: 0.1971 - val_loss: 3.4117

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/AboutElephant-Savanna.jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Predict:  elephant

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/unsplash-image-8iZG31eXkks.jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Predict:  cloud

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/atlantic-bottlenose-dolphin--jumping-high-during-a-dolphin-training-demonstration-154724035-59ce93949abed50011352530.jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predict:  dolphin

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/foundations-little-scholars-kids-school-chairs-12-in-seat-height_main_1.jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predict:  chair

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/fresh-orange.png'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Predict:  orange

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/images (2).jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Predict:  camel

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/Lion_waiting_in_Namibia.jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# Predict:  lion

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/images (6).jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Predict:  crab

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/images (7).jpg'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Predict:  rocket

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.utils import to_categorical
from keras.utils import img_to_array
from keras.preprocessing.image import load_img

class_labels = [
    'apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle',
    'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle',
    'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
    'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard',
    'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain',
    'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree',
    'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket',
    'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider',
    'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor',
    'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm'
]

img_path = '/content/roll-bicycle-company-c1-city-bike-step-thru-405434-12.png'
img = load_img(img_path, target_size=(32,32))

img_array = img_to_array(img)
img_array = img_array.reshape(1, 32*32*3)
img_array = img_array.astype('float32') / 255.0

plt.imshow(load_img(img_path))
plt.axis('off')
plt.show()

prediction_index = np.argmax(model.predict(img_array), axis=-1)[0]
predicted_label = class_labels[prediction_index]
print("Predict: ", predicted_label)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Predict:  bicycle
